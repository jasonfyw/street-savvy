# %%
import requests
import json
import urllib.parse

# %%
# RESTAURANTS

COORDS = [
    (43.6608159, -79.3969058),
    (43.6646275, -79.3740106),
    (43.6486219, -79.381671),
    (43.6502521, -79.3591404),
    (43.6440103, -79.4031715),
    (43.6587132, -79.4188571),
    (43.6427215, -79.4269466),
    (43.6769665, -79.3888378),
    (43.6735522, -79.4119263),
    (43.6699204, -79.4366455),
    (43.6546458, -79.4452286),
    (43.6401749, -79.450078),
    (43.665326, -79.4643259),
    (43.6515718, -79.4675446),
    (43.6506519, -79.4831486),
    (43.6896443, -79.4023347),
    (43.6858273, -79.4267535),
    (43.6848187, -79.4496489),
    (43.6816531, -79.4735527),
    (43.7254598, -79.4522667)
]

RADIUS = 1000
TYPE = 'restaurant'
BASE_URL = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={}%2C{}&radius={}&type={}&fields=formatted_address,current_opening_hours,formatted_phone_number,website,editorial_summary,price_level,rating,serves_breakfast,serves_dinner,serves_lunch,serves_vegetarian_food,user_ratings_total&key=AIzaSyC1KxLWjVA7yLjNawotTvIAzxeV1515p2Q'
NEXT_URL = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC1KxLWjVA7yLjNawotTvIAzxeV1515p2Q&pagetoken='

file_format = 'data/{}-zone{}-{}.json'

# %%
for coord in COORDS:
    print(BASE_URL.format(coord[0], coord[1], RADIUS, TYPE))
    print('\n')
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=43.6608159%2C-79.3969058&radius=1000&type=restaurant&fields=formatted_address,current_opening_hours,formatted_phone_number,website,editorial_summary,price_level,rating,serves_breakfast,serves_dinner,serves_lunch,serves_vegetarian_food,user_ratings_total&key=AIzaSyC1KxLWjVA7yLjNawotTvIAzxeV1515p2Q
#
#
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=43.6646275%2C-79.3740106&radius=1000&type=restaurant&fields=formatted_address,current_opening_hours,formatted_phone_number,website,editorial_summary,price_level,rating,serves_breakfast,serves_dinner,serves_lunch,serves_vegetarian_food,user_ratings_total&key=AIzaSyC1KxLWjVA7yLjNawotTvIAzxeV1515p2Q
#
#
# ...

# %%
# THINGS TO DO

COORDS = [
    (43.653404, -79.369183),
    (43.644117, -79.412516),
    (43.644908, -79.457396),
    (43.681219, -79.361887),
    (43.679357, -79.402979),
    (43.666940, -79.448298)
]

RADIUS = 2000
TYPES = [
    'art_gallery',
    'movie_theater',
    'museum',
    'night_club',
    'park',
    'tourist_attraction'
]
BASE_URL = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={}%2C{}&radius={}&type={}&fields=formatted_address,current_opening_hours,formatted_phone_number,website,editorial_summary,price_level,rating,user_ratings_total&key=AIzaSyC1KxLWjVA7yLjNawotTvIAzxeV1515p2Q'
NEXT_URL = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC1KxLWjVA7yLjNawotTvIAzxeV1515p2Q&pagetoken='

file_format = 'data/{}-zone{}-{}.json'

# %%
for t in TYPES:
    for coord in COORDS:
        print(BASE_URL.format(coord[0], coord[1], RADIUS, t))
        print('\n')
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=43.653404%2C-79.369183&radius=2000&type=art_gallery&fields=formatted_address,current_opening_hours,formatted_phone_number,website,editorial_summary,price_level,rating,user_ratings_total&key=AIzaSyC1KxLWjVA7yLjNawotTvIAzxeV1515p2Q
#
#
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=43.644117%2C-79.412516&radius=2000&type=art_gallery&fields=formatted_address,current_opening_hours,formatted_phone_number,website,editorial_summary,price_level,rating,user_ratings_total&key=AIzaSyC1KxLWjVA7yLjNawotTvIAzxeV1515p2Q
#
#
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=43.644908%2C-79.457396&radius=2000&type=art_gallery&fields=formatted_address,current_opening_hours,formatted_phone_number,website,editorial_summary,price_level,rating,user_ratings_total&key=AIzaSyC1KxLWjVA7yLjNawotTvIAzxeV1515p2Q
#
#
# ...
